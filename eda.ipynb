# %% [markdown]
# ## Library imports

# %%
from util import data_address
data_address
# Out:
# './data/'

# %%
import pandas as pd
import numpy as np



from tqdm import tqdm
tqdm.pandas()

from ydata_profiling import ProfileReport

# %%
df_raw = pd.read_pickle(data_address+"df_merged.pkl")
df_raw
# Out:
#        index  chapter  degrees distractor  \
# 0          0    32639      160       babb
# 1          1    32639      160       babb
# 2          2    32658       70       babb
# 3          3    32658       70       babb
# 4          4   130550       10       babb
# ...      ...      ...      ...        ...
# 19195  12795   162129      160       none
# 19196  12796    75242      170       none
# 19197  12797    75242      170       none
# 19198  12798    14653      160       none
# 19199  12799    14653      160       none
#
#                                                 filename gender  mic  \
# 0      distant-16k/speech/test/rm4/babb/sp4899/Lab41-...      F    1
# 1      distant-16k/speech/test/rm4/babb/sp4899/Lab41-...      F    5
# 2      distant-16k/speech/test/rm4/babb/sp4899/Lab41-...      F    5
# 3      distant-16k/speech/test/rm4/babb/sp4899/Lab41-...      F    1
# 4      distant-16k/speech/test/rm4/babb/sp1447/Lab41-...      F    1
# ...                                                  ...    ...  ...
# 19195  distant-16k/speech/train/rm4/none/sp2673/Lab41...      M    1
# 19196  distant-16k/speech/train/rm4/none/sp1212/Lab41...      F    5
# 19197  distant-16k/speech/train/rm4/none/sp1212/Lab41...      F    1
# 19198  distant-16k/speech/train/rm4/none/sp1212/Lab41...      F    1
# 19199  distant-16k/speech/train/rm4/none/sp1212/Lab41...      F    5
#
#                                               query_name room  segment  ...  \
# 0      Lab41-SRI-VOiCES-rm4-babb-sp4899-ch032639-sg00...  rm4       29  ...
# 1      Lab41-SRI-VOiCES-rm4-babb-sp4899-ch032639-sg00...  rm4       29  ...
# 2      Lab41-SRI-VOiCES-rm4-babb-sp4899-ch032658-sg00...  rm4       12  ...
# 3      Lab41-SRI-VOiCES-rm4-babb-sp4899-ch032658-sg00...  rm4       12  ...
# 4      Lab41-SRI-VOiCES-rm4-babb-sp1447-ch130550-sg00...  rm4       26  ...
# ...                                                  ...  ...      ...  ...
# 19195  Lab41-SRI-VOiCES-rm4-none-sp2673-ch162129-sg00...  rm4       27  ...
# 19196  Lab41-SRI-VOiCES-rm4-none-sp1212-ch075242-sg00...  rm4       16  ...
# 19197  Lab41-SRI-VOiCES-rm4-none-sp1212-ch075242-sg00...  rm4       16  ...
# 19198  Lab41-SRI-VOiCES-rm4-none-sp1212-ch014653-sg00...  rm4        3  ...
# 19199  Lab41-SRI-VOiCES-rm4-none-sp1212-ch014653-sg00...  rm4        3  ...
#
#                                               transcript  noisy_length  \
# 0      and i got on with the lesson very badly i am s...        255040
# 1      and i got on with the lesson very badly i am s...        255040
# 2      and ran upstairs to put away the host of littl...        258000
# 3      and ran upstairs to put away the host of littl...        258000
# 4                           he was inexhaustibly voluble         58720
# ...                                                  ...           ...
# 19195  and away with it we ought all to say if social...        239840
# 19196  and zip dropped from the boy's arms not into t...        269040
# 19197  and zip dropped from the boy's arms not into t...        269040
# 19198  for for the sake of my reputation i suggested ...        256080
# 19199  for for the sake of my reputation i suggested ...        256080
#
#       noisy_sr  noisy_time  source_length  source_sr  source_time  category  \
# 0        16000      15.940         255040      16000       15.940      test
# 1        16000      15.940         255040      16000       15.940      test
# 2        16000      16.125         258000      16000       16.125      test
# 3        16000      16.125         258000      16000       16.125      test
# 4        16000       3.670          58720      16000        3.670      test
# ...        ...         ...            ...        ...          ...       ...
# 19195    16000      14.990         239840      16000       14.990     train
# 19196    16000      16.815         269040      16000       16.815     train
# 19197    16000      16.815         269040      16000       16.815     train
# 19198    16000      16.005         256080      16000       16.005     train
# 19199    16000      16.005         256080      16000       16.005     train
#
#        frequency                                             signal
# 0          16000  [406, 725, 603, 562, 418, 343, 257, 254, 288, ...
# 1          16000  [285, 611, 451, 492, 377, 313, 201, 19, -114, ...
# 2          16000  [145, 76, -353, -529, -706, -886, -719, -536, ...
# 3          16000  [-147, -332, -326, -291, -211, -85, -2, 66, 10...
# 4          16000  [94, 179, 164, 154, 115, 78, 76, 84, 52, 28, -...
# ...          ...                                                ...
# 19195      16000  [-64, -133, -146, -149, -122, -118, -133, -174...
# 19196      16000  [-372, -677, -647, -637, -622, -614, -662, -68...
# 19197      16000  [110, 178, 162, 165, 214, 241, 224, 213, 178, ...
# 19198      16000  [16, 30, 8, 2, 8, 31, 61, 62, 33, -6, -2, 35, ...
# 19199      16000  [-2, 33, -11, -42, -33, -11, -22, -95, -126, -...
#
# [19200 rows x 22 columns]

# %% [markdown]
# ##

# %%
df_raw.isna().sum()
# Out:
# index            0
# chapter          0
# degrees          0
# distractor       0
# filename         0
# gender           0
# mic              0
# query_name       0
# room             0
# segment          0
# source           0
# speaker          0
# transcript       0
# noisy_length     0
# noisy_sr         0
# noisy_time       0
# source_length    0
# source_sr        0
# source_time      0
# category         0
# frequency        0
# signal           0
# dtype: int64

# %%
profile = ProfileReport(df_raw, title="VoiCE index Report")

# %%
profile.to_file("VoiCE_DEV index Report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile.to_widgets()
# Out:
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# ## EDA of simple processed data

# %%
df_processed_simple = pd.read_pickle("data/df_processed_simple.pkl")
df_processed_simple
# Out:
#        index  chapter  degrees  distractor  \
# 0          0    32639      160           2
# 1          1    32639      160           2
# 2          2    32658       70           2
# 3          3    32658       70           2
# 4          4   130550       10           2
# ...      ...      ...      ...         ...
# 19195  12795   162129      160           0
# 19196  12796    75242      170           0
# 19197  12797    75242      170           0
# 19198  12798    14653      160           0
# 19199  12799    14653      160           0
#
#                                                 filename  gender  mic  \
# 0      distant-16k/speech/test/rm4/babb/sp4899/Lab41-...       0    1
# 1      distant-16k/speech/test/rm4/babb/sp4899/Lab41-...       0    5
# 2      distant-16k/speech/test/rm4/babb/sp4899/Lab41-...       0    5
# 3      distant-16k/speech/test/rm4/babb/sp4899/Lab41-...       0    1
# 4      distant-16k/speech/test/rm4/babb/sp1447/Lab41-...       0    1
# ...                                                  ...     ...  ...
# 19195  distant-16k/speech/train/rm4/none/sp2673/Lab41...       1    1
# 19196  distant-16k/speech/train/rm4/none/sp1212/Lab41...       0    5
# 19197  distant-16k/speech/train/rm4/none/sp1212/Lab41...       0    1
# 19198  distant-16k/speech/train/rm4/none/sp1212/Lab41...       0    1
# 19199  distant-16k/speech/train/rm4/none/sp1212/Lab41...       0    5
#
#                                               query_name  room  segment  ...  \
# 0      Lab41-SRI-VOiCES-rm4-babb-sp4899-ch032639-sg00...     3       29  ...
# 1      Lab41-SRI-VOiCES-rm4-babb-sp4899-ch032639-sg00...     3       29  ...
# 2      Lab41-SRI-VOiCES-rm4-babb-sp4899-ch032658-sg00...     3       12  ...
# 3      Lab41-SRI-VOiCES-rm4-babb-sp4899-ch032658-sg00...     3       12  ...
# 4      Lab41-SRI-VOiCES-rm4-babb-sp1447-ch130550-sg00...     3       26  ...
# ...                                                  ...   ...      ...  ...
# 19195  Lab41-SRI-VOiCES-rm4-none-sp2673-ch162129-sg00...     3       27  ...
# 19196  Lab41-SRI-VOiCES-rm4-none-sp1212-ch075242-sg00...     3       16  ...
# 19197  Lab41-SRI-VOiCES-rm4-none-sp1212-ch075242-sg00...     3       16  ...
# 19198  Lab41-SRI-VOiCES-rm4-none-sp1212-ch014653-sg00...     3        3  ...
# 19199  Lab41-SRI-VOiCES-rm4-none-sp1212-ch014653-sg00...     3        3  ...
#
#       source_time  category frequency  signal_max  signal_min  signal_mean  \
# 0          15.940      test     16000       14940      -14614    -0.015005
# 1          15.940      test     16000       14027      -15073     0.073883
# 2          16.125      test     16000        9857      -10585    -0.028159
# 3          16.125      test     16000       16185      -13671    -0.027550
# 4           3.670      test     16000        6889       -7245    -0.034877
# ...           ...       ...       ...         ...         ...          ...
# 19195      14.990     train     16000        7926       -5264    -0.062888
# 19196      16.815     train     16000       10418       -8685    -0.061604
# 19197      16.815     train     16000       11344      -13412     0.041314
# 19198      16.005     train     16000        6780       -7170     0.023211
# 19199      16.005     train     16000        5384       -5311     0.056510
#
#        signal_count  signal_positive  signal_negative signal_zero
# 0            255040           125552           129342         146
# 1            255040           127889           127077          74
# 2            258000           128626           129298          76
# 3            258000           124656           133210         134
# 4             58720            29624            29052          44
# ...             ...              ...              ...         ...
# 19195        239840           118661           120784         395
# 19196        269040           134006           134918         116
# 19197        269040           135017           133788         235
# 19198        256080           127122           128582         376
# 19199        256080           127645           128248         187
#
# [19200 rows x 28 columns]

# %%
profile_processed = ProfileReport(df_processed_simple, title="VoiCE Simplely Processed Report")

# %%
profile_processed.to_file("VoiCE_DEV Simplely Processed Report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile_processed.to_widgets()
# Out:
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %% [markdown]
# ### Box whisker plot on source_time

# %%
import matplotlib.pyplot as plt

# Create a box and whisker plot
plt.boxplot(df_raw['source_time'], vert=False)

# Set the title and labels
plt.title('Box and Whisker Plot - Source Length')
plt.xlabel('Source Time')

# Show the plot
plt.show()

# %%
df_raw.columns
# Out:
# Index(['index', 'chapter', 'degrees', 'distractor', 'filename', 'gender',
#        'mic', 'query_name', 'room', 'segment', 'source', 'speaker',
#        'transcript', 'noisy_length', 'noisy_sr', 'noisy_time', 'source_length',
#        'source_sr', 'source_time', 'category', 'frequency', 'signal'],
#       dtype='object')

# %%
# Create a box and whisker plot using Plotly
import plotly.express as px

fig = px.box(df_raw, x='source_time', title='Box and Whisker Plot - Source Length')
# fig.update_layout(xaxis_title='Source Length', yaxis_title='Length')

fig.show()

# %% [markdown]
# ## Cosine Similarity

# %% [markdown]
# ### Raw and distracted data

# %%
## TODO

# %% [markdown]
# ### Raw and dinoised distracted data

# %%
## TODO
